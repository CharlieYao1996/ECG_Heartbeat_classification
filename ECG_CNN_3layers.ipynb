# %%
import os
import numpy as np
import pandas as pd
from sklearn.metrics import recall_score, precision_score, f1_score, confusion_matrix

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split

# %%
# =========================
# 1. load data & Dataset define
# =========================
data_dir = r".\archive"
train_path = os.path.join(data_dir, "mitbih_train.csv")
test_path = os.path.join(data_dir, "mitbih_test.csv")

train_df = pd.read_csv(train_path, header=None)
test_df = pd.read_csv(test_path, header=None)

X_train = train_df.iloc[:, :-1].values
y_train = train_df.iloc[:, -1].values.astype(int)

X_test = test_df.iloc[:, :-1].values
y_test = test_df.iloc[:, -1].values.astype(int)

# Z-score per sample
X_train = (X_train - X_train.mean(axis=1, keepdims=True)) / (X_train.std(axis=1, keepdims=True) + 1e-8)
X_test = (X_test - X_test.mean(axis=1, keepdims=True)) / (X_test.std(axis=1, keepdims=True) + 1e-8)

# reshape: (samples, 1, 187)
X_train = X_train[:, np.newaxis, :]
X_test = X_test[:, np.newaxis, :]

X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# %%
# =========================
# 2. 定義 CNN 模型
# =========================
class ECG_CNN(nn.Module):
    def __init__(self, num_classes=5):
        super(ECG_CNN, self).__init__()
        self.conv1 = nn.Conv1d(1, 32, kernel_size=5, padding=2)
        self.conv2 = nn.Conv1d(32, 64, kernel_size=5, padding=2)
        self.conv3 = nn.Conv1d(64, 128, kernel_size=5, padding=2)
        self.relu = nn.ReLU()
        self.gap = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.relu(self.conv3(x))
        x = self.gap(x).squeeze(-1)
        x = self.fc(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
save_dir = os.path.join(data_dir, "models")
os.makedirs(save_dir, exist_ok=True)
model_path = os.path.join(save_dir, "ECG_CNN_3layers.pt")

# %%
# =========================
# 3.Training
# =========================
#normal split
# dataset = TensorDataset(X_train_tensor, y_train_tensor)
# train_size = int(0.8 * len(dataset))
# val_size = len(dataset) - train_size
# train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
#keep same seed for all model
np.random.seed(42)
#Stratified split
class_ranges = [
    (0, 72471),
    (72471, 74694),
    (74694, 80483),
    (80483, 81123),
    (81123, 87554)
]

train_indices = []
val_indices = []

for start, end in class_ranges:
    idx = np.arange(start, end)
    np.random.shuffle(idx)  # shuffle
    n_val = int(len(idx) * 0.2)
    val_indices.extend(idx[:n_val])
    train_indices.extend(idx[n_val:])
    
#  tensor
train_dataset = TensorDataset(X_train_tensor[train_indices], y_train_tensor[train_indices])
val_dataset = TensorDataset(X_train_tensor[val_indices], y_train_tensor[val_indices])

#data loader
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)


model = ECG_CNN().to(device)
criterion = nn.CrossEntropyLoss()  
#optimizer = optim.Adam(model.parameters(), lr=1e-3)
optimizer = optim.AdamW(model.parameters(), lr=1e-3,weight_decay=1e-3)

num_epochs = 100
best_val_loss = float("inf")
patience_es = 15
no_improve_count = 0
for epoch in range(num_epochs):
    # ---- Training ----
    model.train()
    train_loss = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * X.size(0)
    train_loss /= len(train_loader.dataset)

    # ---- Validation ----
    model.eval()
    val_loss = 0
    correct = 0
    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            val_loss += loss.item() * X.size(0)
            preds = outputs.argmax(dim=1)
            correct += (preds == y).sum().item()
    val_loss /= len(val_loader.dataset)
    val_acc = correct / len(val_loader.dataset)

    print(f"Epoch {epoch+1}/{num_epochs} - "
          f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")

    # ---- Save Best ----
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), model_path)
        print("Best model saved.")
        no_improve_count = 0
    else:
        no_improve_count += 1
        if no_improve_count >= patience_es:
            print(f"Early stopping at epoch {epoch+1}")
            break
# Out:
# Epoch 1/100 - Train Loss: 0.4555 | Val Loss: 0.3743 | Val Acc: 0.8945
# Best model saved.
# Epoch 2/100 - Train Loss: 0.2885 | Val Loss: 0.2823 | Val Acc: 0.9240
# Best model saved.
# Epoch 3/100 - Train Loss: 0.2229 | Val Loss: 0.2107 | Val Acc: 0.9387
# Best model saved.
# Epoch 4/100 - Train Loss: 0.1944 | Val Loss: 0.1882 | Val Acc: 0.9485
# Best model saved.
# Epoch 5/100 - Train Loss: 0.1790 | Val Loss: 0.1843 | Val Acc: 0.9470
# Best model saved.
# Epoch 6/100 - Train Loss: 0.1640 | Val Loss: 0.1602 | Val Acc: 0.9562
# Best model saved.
# Epoch 7/100 - Train Loss: 0.1547 | Val Loss: 0.1741 | Val Acc: 0.9509
# Epoch 8/100 - Train Loss: 0.1462 | Val Loss: 0.1508 | Val Acc: 0.9602
# Best model saved.
# Epoch 9/100 - Train Loss: 0.1400 | Val Loss: 0.1490 | Val Acc: 0.9608
# Best model saved.
# Epoch 10/100 - Train Loss: 0.1354 | Val Loss: 0.1412 | Val Acc: 0.9622
# Best model saved.
# Epoch 11/100 - Train Loss: 0.1309 | Val Loss: 0.1498 | Val Acc: 0.9605
# Epoch 12/100 - Train Loss: 0.1261 | Val Loss: 0.1323 | Val Acc: 0.9638
# Best model saved.
# Epoch 13/100 - Train Loss: 0.1225 | Val Loss: 0.1432 | Val Acc: 0.9610
# Epoch 14/100 - Train Loss: 0.1183 | Val Loss: 0.1281 | Val Acc: 0.9641
# Best model saved.
# Epoch 15/100 - Train Loss: 0.1164 | Val Loss: 0.1368 | Val Acc: 0.9638
# Epoch 16/100 - Train Loss: 0.1124 | Val Loss: 0.1262 | Val Acc: 0.9646
# Best model saved.
# Epoch 17/100 - Train Loss: 0.1093 | Val Loss: 0.1221 | Val Acc: 0.9666
# Best model saved.
# Epoch 18/100 - Train Loss: 0.1062 | Val Loss: 0.1225 | Val Acc: 0.9669
# Epoch 19/100 - Train Loss: 0.1037 | Val Loss: 0.1209 | Val Acc: 0.9670
# Best model saved.
# Epoch 20/100 - Train Loss: 0.1006 | Val Loss: 0.1711 | Val Acc: 0.9565
# Epoch 21/100 - Train Loss: 0.0996 | Val Loss: 0.1108 | Val Acc: 0.9692
# Best model saved.
# Epoch 22/100 - Train Loss: 0.0950 | Val Loss: 0.1088 | Val Acc: 0.9693
# Best model saved.
# Epoch 23/100 - Train Loss: 0.0943 | Val Loss: 0.1057 | Val Acc: 0.9702
# Best model saved.
# Epoch 24/100 - Train Loss: 0.0916 | Val Loss: 0.1082 | Val Acc: 0.9689
# Epoch 25/100 - Train Loss: 0.0915 | Val Loss: 0.1033 | Val Acc: 0.9716
# Best model saved.
# Epoch 26/100 - Train Loss: 0.0880 | Val Loss: 0.1088 | Val Acc: 0.9713
# Epoch 27/100 - Train Loss: 0.0876 | Val Loss: 0.1022 | Val Acc: 0.9724
# Best model saved.
# Epoch 28/100 - Train Loss: 0.0846 | Val Loss: 0.0987 | Val Acc: 0.9723
# Best model saved.
# Epoch 29/100 - Train Loss: 0.0842 | Val Loss: 0.1000 | Val Acc: 0.9722
# Epoch 30/100 - Train Loss: 0.0830 | Val Loss: 0.1182 | Val Acc: 0.9664
# Epoch 95/100 - Train Loss: 0.0401 | Val Loss: 0.0757 | Val Acc: 0.9808
# Epoch 96/100 - Train Loss: 0.0394 | Val Loss: 0.0773 | Val Acc: 0.9810
# Epoch 97/100 - Train Loss: 0.0393 | Val Loss: 0.0882 | Val Acc: 0.9794
# Epoch 98/100 - Train Loss: 0.0388 | Val Loss: 0.0781 | Val Acc: 0.9808
# Epoch 99/100 - Train Loss: 0.0391 | Val Loss: 0.0830 | Val Acc: 0.9802
# Epoch 100/100 - Train Loss: 0.0375 | Val Loss: 0.0797 | Val Acc: 0.9821

# %%
# =========================
# evaluation
# =========================
test_ds = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_ds, batch_size=128, shuffle=False)

# load model
model = ECG_CNN().to(device)
model.load_state_dict(torch.load(model_path))
model.eval()
#eval
preds, labels = [], []
with torch.no_grad():
    for xb, yb in test_loader:
        xb, yb = xb.to(device), yb.to(device)
        out = model(xb)
        pred = torch.argmax(out, dim=1)
        preds.extend(pred.cpu().numpy())
        labels.extend(yb.cpu().numpy())
#save csv
csv_path = os.path.join(save_dir, "test_pred.csv")
pd.DataFrame({"y_true": labels, "y_pred": preds}).to_csv(csv_path, index=False)
print(f"Evaluation CSV saved at {csv_path}")
# Out:
# Evaluation CSV saved at .\archive\models\test_pred.csv

# %%
# =========================
# confusion matrix & metrics
# =========================
cm = confusion_matrix(labels, preds, labels=list(range(5)))

print("===== Confusion Matrix =====")
print(cm)

# 計算各類 one-vs-all 指標
metrics_per_class = {"recall": [], "specificity": [], "precision": [], "f1": []}
class_counts = cm.sum(axis=1)
total_samples = class_counts.sum()
weights = class_counts / total_samples

for i in range(5):
    TP = cm[i, i]
    FP = cm[:, i].sum() - TP
    FN = cm[i, :].sum() - TP
    TN = cm.sum() - (TP + FP + FN)

    recall_i = TP / (TP + FN + 1e-8)
    specificity_i = TN / (TN + FP + 1e-8)
    precision_i = TP / (TP + FP + 1e-8)
    f1_i = 2 * recall_i * precision_i / (recall_i + precision_i + 1e-8)

    metrics_per_class["recall"].append(recall_i)
    metrics_per_class["specificity"].append(specificity_i)
    metrics_per_class["precision"].append(precision_i)
    metrics_per_class["f1"].append(f1_i)

macro_avg_metrics = {k: np.mean(v) for k, v in metrics_per_class.items()}
weighted_avg_metrics = {k: np.sum(np.array(v) * weights) for k, v in metrics_per_class.items()}

print("\n===== Per-Class Metrics =====")
for k, v in metrics_per_class.items():
    print(f"{k}: {np.round(v, 4)}")
print("\n===== Macro-Average Metrics =====")
for k, v in macro_avg_metrics.items():
    print(f"{k}: {v:.4f}")
print("\n===== Weighted-Average Metrics =====")
for k, v in weighted_avg_metrics.items():
    print(f"{k}: {v:.4f}")
# Out:
# ===== Confusion Matrix =====
# [[17991    81    35     7     4]
#  [  147   400     4     5     0]
#  [   49     6  1377    14     2]
#  [   13     0    22   127     0]
#  [   20     1     4     0  1583]]
#
# ===== Per-Class Metrics =====
# recall: [0.993  0.7194 0.951  0.784  0.9845]
# specificity: [0.9393 0.9959 0.9968 0.9988 0.9997]
# precision: [0.9874 0.8197 0.9549 0.8301 0.9962]
# f1: [0.9902 0.7663 0.9529 0.8063 0.9903]
#
# ===== Macro-Average Metrics =====
# recall: 0.8864
# specificity: 0.9861
# precision: 0.9177
# f1: 0.9012
#
# ===== Weighted-Average Metrics =====
# recall: 0.9811
# specificity: 0.9494
# precision: 0.9805
# f1: 0.9807
